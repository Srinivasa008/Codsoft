# %%
pip install pingouin
# Out:
# Requirement already satisfied: pingouin in c:\users\swapn\anaconda3\lib\site-packages (0.5.3)
# Requirement already satisfied: seaborn>=0.11 in c:\users\swapn\anaconda3\lib\site-packages (from pingouin) (0.11.2)
# Requirement already satisfied: scipy>=1.7 in c:\users\swapn\anaconda3\lib\site-packages (from pingouin) (1.7.1)
# Requirement already satisfied: pandas-flavor>=0.2.0 in c:\users\swapn\anaconda3\lib\site-packages (from pingouin) (0.6.0)
# Requirement already satisfied: matplotlib>=3.0.2 in c:\users\swapn\anaconda3\lib\site-packages (from pingouin) (3.4.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# Requirement already satisfied: scikit-learn in c:\users\swapn\anaconda3\lib\site-packages (from pingouin) (1.3.2)
# Requirement already satisfied: pandas>=1.0 in c:\users\swapn\anaconda3\lib\site-packages (from pingouin) (2.1.3)
# Requirement already satisfied: statsmodels>=0.13 in c:\users\swapn\anaconda3\lib\site-packages (from pingouin) (0.14.0)
# Requirement already satisfied: outdated in c:\users\swapn\anaconda3\lib\site-packages (from pingouin) (0.2.2)
# Requirement already satisfied: tabulate in c:\users\swapn\anaconda3\lib\site-packages (from pingouin) (0.8.10)
# Requirement already satisfied: numpy>=1.19 in c:\users\swapn\anaconda3\lib\site-packages (from pingouin) (1.22.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\swapn\anaconda3\lib\site-packages (from matplotlib>=3.0.2->pingouin) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\swapn\anaconda3\lib\site-packages (from matplotlib>=3.0.2->pingouin) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\swapn\anaconda3\lib\site-packages (from matplotlib>=3.0.2->pingouin) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\swapn\anaconda3\lib\site-packages (from matplotlib>=3.0.2->pingouin) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\swapn\anaconda3\lib\site-packages (from matplotlib>=3.0.2->pingouin) (1.3.1)
# Requirement already satisfied: six in c:\users\swapn\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.0.2->pingouin) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\swapn\anaconda3\lib\site-packages (from pandas>=1.0->pingouin) (2021.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\swapn\anaconda3\lib\site-packages (from pandas>=1.0->pingouin) (2023.3)
# Requirement already satisfied: xarray in c:\users\swapn\anaconda3\lib\site-packages (from pandas-flavor>=0.2.0->pingouin) (2023.11.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\swapn\anaconda3\lib\site-packages (from statsmodels>=0.13->pingouin) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\swapn\anaconda3\lib\site-packages (from statsmodels>=0.13->pingouin) (23.2)
# Requirement already satisfied: littleutils in c:\users\swapn\anaconda3\lib\site-packages (from outdated->pingouin) (0.2.2)
# Requirement already satisfied: requests in c:\users\swapn\anaconda3\lib\site-packages (from outdated->pingouin) (2.26.0)
# Requirement already satisfied: setuptools>=44 in c:\users\swapn\anaconda3\lib\site-packages (from outdated->pingouin) (58.0.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\swapn\anaconda3\lib\site-packages (from requests->outdated->pingouin) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\swapn\anaconda3\lib\site-packages (from requests->outdated->pingouin) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\swapn\anaconda3\lib\site-packages (from requests->outdated->pingouin) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\swapn\anaconda3\lib\site-packages (from requests->outdated->pingouin) (1.26.7)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\swapn\anaconda3\lib\site-packages (from scikit-learn->pingouin) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\swapn\anaconda3\lib\site-packages (from scikit-learn->pingouin) (2.2.0)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)

# %%
pip install datasist
# Out:
# Requirement already satisfied: datasist in c:\users\swapn\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: Joblib in c:\users\swapn\anaconda3\lib\site-packages (from datasist) (1.3.2)
# Requirement already satisfied: numpy in c:\users\swapn\anaconda3\lib\site-packages (from datasist) (1.22.4)
# Requirement already satisfied: matplotlib in c:\users\swapn\anaconda3\lib\site-packages (from datasist) (3.4.3)
# Requirement already satisfied: scikit-learn in c:\users\swapn\anaconda3\lib\site-packages (from datasist) (1.3.2)
# Requirement already satisfied: nltk in c:\users\swapn\anaconda3\lib\site-packages (from datasist) (3.6.5)
# Requirement already satisfied: seaborn in c:\users\swapn\anaconda3\lib\site-packages (from datasist) (0.11.2)
# Requirement already satisfied: pandas in c:\users\swapn\anaconda3\lib\site-packages (from datasist) (2.1.3)
# Requirement already satisfied: jupyter in c:\users\swapn\anaconda3\lib\site-packages (from datasist) (1.0.0)
# Requirement already satisfied: nbconvert in c:\users\swapn\anaconda3\lib\site-packages (from jupyter->datasist) (6.1.0)
# Requirement already satisfied: ipykernel in c:\users\swapn\anaconda3\lib\site-packages (from jupyter->datasist) (6.4.1)
# Requirement already satisfied: qtconsole in c:\users\swapn\anaconda3\lib\site-packages (from jupyter->datasist) (5.1.1)
# Requirement already satisfied: notebook in c:\users\swapn\anaconda3\lib\site-packages (from jupyter->datasist) (6.4.5)
# Requirement already satisfied: ipywidgets in c:\users\swapn\anaconda3\lib\site-packages (from jupyter->datasist) (7.6.5)
# Requirement already satisfied: jupyter-console in c:\users\swapn\anaconda3\lib\site-packages (from jupyter->datasist) (6.4.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\swapn\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\swapn\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\swapn\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (0.1.2)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in c:\users\swapn\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (5.1.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\swapn\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (1.4.1)
# Requirement already satisfied: ipython-genutils in c:\users\swapn\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (0.2.0)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in c:\users\swapn\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (7.29.0)
# Requirement already satisfied: backcall in c:\users\swapn\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->datasist) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\swapn\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->datasist) (0.18.0)
# Requirement already satisfied: pickleshare in c:\users\swapn\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->datasist) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\swapn\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->datasist) (3.0.20)
# Requirement already satisfied: colorama in c:\users\swapn\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->datasist) (0.4.4)
# Requirement already satisfied: setuptools>=18.5 in c:\users\swapn\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->datasist) (58.0.4)
# Requirement already satisfied: pygments in c:\users\swapn\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->datasist) (2.10.0)
# Requirement already satisfied: decorator in c:\users\swapn\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->datasist) (5.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\swapn\anaconda3\lib\site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->jupyter->datasist) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\swapn\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->datasist) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\swapn\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->datasist) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\swapn\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->datasist) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\swapn\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter->datasist) (228)
# Requirement already satisfied: wcwidth in c:\users\swapn\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel->jupyter->datasist) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\swapn\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel->jupyter->datasist) (1.16.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\swapn\anaconda3\lib\site-packages (from ipywidgets->jupyter->datasist) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\swapn\anaconda3\lib\site-packages (from ipywidgets->jupyter->datasist) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\swapn\anaconda3\lib\site-packages (from ipywidgets->jupyter->datasist) (3.5.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\swapn\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->datasist) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\swapn\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->datasist) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\swapn\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->datasist) (21.2.0)
# Requirement already satisfied: prometheus-client in c:\users\swapn\anaconda3\lib\site-packages (from notebook->jupyter->datasist) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\swapn\anaconda3\lib\site-packages (from notebook->jupyter->datasist) (1.8.0)
# Requirement already satisfied: jinja2 in c:\users\swapn\anaconda3\lib\site-packages (from notebook->jupyter->datasist) (2.11.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\swapn\anaconda3\lib\site-packages (from notebook->jupyter->datasist) (0.9.4)
# Requirement already satisfied: argon2-cffi in c:\users\swapn\anaconda3\lib\site-packages (from notebook->jupyter->datasist) (20.1.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\swapn\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->datasist) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\swapn\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter->datasist) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\swapn\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->datasist) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\swapn\anaconda3\lib\site-packages (from jinja2->notebook->jupyter->datasist) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\swapn\anaconda3\lib\site-packages (from matplotlib->datasist) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\swapn\anaconda3\lib\site-packages (from matplotlib->datasist) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\swapn\anaconda3\lib\site-packages (from matplotlib->datasist) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\swapn\anaconda3\lib\site-packages (from matplotlib->datasist) (0.10.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\swapn\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\swapn\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (0.8.4)
# Requirement already satisfied: bleach in c:\users\swapn\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (4.0.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\swapn\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (0.3)
# Requirement already satisfied: defusedxml in c:\users\swapn\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (0.7.1)
# Requirement already satisfied: testpath in c:\users\swapn\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\swapn\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\swapn\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (1.4.3)
# Requirement already satisfied: async-generator in c:\users\swapn\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->datasist) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\swapn\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->datasist) (1.5.1)
# Requirement already satisfied: packaging in c:\users\swapn\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->datasist) (23.2)
# Requirement already satisfied: webencodings in c:\users\swapn\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->datasist) (0.5.1)
# Requirement already satisfied: click in c:\users\swapn\anaconda3\lib\site-packages (from nltk->datasist) (8.0.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\swapn\anaconda3\lib\site-packages (from nltk->datasist) (2021.8.3)
# Requirement already satisfied: tqdm in c:\users\swapn\anaconda3\lib\site-packages (from nltk->datasist) (4.62.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\swapn\anaconda3\lib\site-packages (from pandas->datasist) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\swapn\anaconda3\lib\site-packages (from pandas->datasist) (2021.3)
# Requirement already satisfied: qtpy in c:\users\swapn\anaconda3\lib\site-packages (from qtconsole->jupyter->datasist) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\swapn\anaconda3\lib\site-packages (from scikit-learn->datasist) (2.2.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\swapn\anaconda3\lib\site-packages (from scikit-learn->datasist) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)

# %%
pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\users\swapn\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\swapn\anaconda3\lib\site-packages (from geopy) (2.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)

# %%
pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in c:\users\swapn\anaconda3\lib\site-packages (2.6.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\swapn\anaconda3\lib\site-packages (from category_encoders) (1.3.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\swapn\anaconda3\lib\site-packages (from category_encoders) (0.5.2)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\swapn\anaconda3\lib\site-packages (from category_encoders) (0.14.0)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\swapn\anaconda3\lib\site-packages (from category_encoders) (2.1.3)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\swapn\anaconda3\lib\site-packages (from category_encoders) (1.7.1)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\swapn\anaconda3\lib\site-packages (from category_encoders) (1.22.4)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\swapn\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\swapn\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\swapn\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: six in c:\users\swapn\anaconda3\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\swapn\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\swapn\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\swapn\anaconda3\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (23.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)

# %%
pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\swapn\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\swapn\anaconda3\lib\site-packages (from imblearn) (0.11.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\swapn\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\swapn\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\swapn\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.3.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\swapn\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.7.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\swapn\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.22.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\swapn\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\swapn\anaconda3\lib\site-packages (from sklearn) (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\swapn\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.22.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\swapn\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\swapn\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.2.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\swapn\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\swapn\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\swapn\anaconda3\lib\site-packages)

# %%
import pandas as pd
pd.set_option('display.max_columns',None)
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(18,8)},style='darkgrid')
sns.set_palette('rocket')
from time import time
import pingouin
from scipy.stats import ttest_ind
from datasist.structdata import detect_outliers
from geopy.distance import great_circle
from category_encoders import WOEEncoder
from imblearn.over_sampling import SMOTE
from sklearn.metrics import *
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\swapn\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\swapn\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
train = pd.read_csv("fraudTrain.csv")
train.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street            city state    zip  \
# 0    Banks      F                561 Perry Cove  Moravian Falls    NC  28654
# 1     Gill      F  43039 Riley Greens Suite 393          Orient    WA  99160
# 2  Sanchez      M      594 White Dale Suite 530      Malad City    ID  83252
# 3    White      M   9443 Cynthia Court Apt. 038         Boulder    MT  59632
# 4   Garcia      M              408 Bradley Rest        Doe Hill    VA  24433
#
#        lat      long  city_pop                                job         dob  \
# 0  36.0788  -81.1781      3495          Psychologist, counselling  1988-03-09
# 1  48.8878 -118.2105       149  Special educational needs teacher  1978-06-21
# 2  42.1808 -112.2620      4154        Nature conservation officer  1962-01-19
# 3  46.2306 -112.1138      1939                    Patent attorney  1967-01-12
# 4  38.4207  -79.4629        99     Dance movement psychotherapist  1986-03-28
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# 1  1f76529f8574734946361c461b024d99  1325376044  49.159047 -118.186462
# 2  a1a22d70485983eac12b5b88dad1cf95  1325376051  43.150704 -112.154481
# 3  6b849c168bdad6f867558c3793159a81  1325376076  47.034331 -112.561071
# 4  a41d7549acf90789359a9aa5346dcb46  1325376186  38.674999  -78.632459
#
#    is_fraud
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
test = pd.read_csv("fraudTest.csv")
test.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street        city state    zip  \
# 0   Elliott      M            351 Darlene Green    Columbia    SC  29209
# 1  Williams      F             3638 Marsh Union     Altonah    UT  84002
# 2     Lopez      F         9333 Valentine Point    Bellmore    NY  11710
# 3  Williams      M  32941 Krystal Mill Apt. 552  Titusville    FL  32780
# 4    Massey      M     5783 Evan Roads Apt. 465    Falmouth    MI  49632
#
#        lat      long  city_pop                     job         dob  \
# 0  33.9659  -80.9355    333497     Mechanical engineer  1968-03-19
# 1  40.3207 -110.4360       302  Sales professional, IT  1990-01-17
# 2  40.6729  -73.5365     34496       Librarian, public  1970-10-21
# 3  28.5697  -80.8191     54767            Set designer  1987-07-25
# 4  44.2529  -85.0170      1126      Furniture designer  1955-07-06
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  2da90c7d74bd46a0caf3777415b3ebd3  1371816865  33.986391  -81.200714
# 1  324cc204407e99f51b0d6ca0055005e7  1371816873  39.450498 -109.960431
# 2  c81755dbbbea9d5c77f094348a7579be  1371816893  40.495810  -74.196111
# 3  2159175b9efe66dc301f149d3d5abf8c  1371816915  28.812398  -80.883061
# 4  57ff021bd3f328f8738bb535c302a31b  1371816917  44.959148  -85.884734
#
#    is_fraud
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
train['split'] = 'train'
test['split']='test'
df = pd.concat([train,test],axis=0).reset_index(drop=True)
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street            city state    zip  \
# 0    Banks      F                561 Perry Cove  Moravian Falls    NC  28654
# 1     Gill      F  43039 Riley Greens Suite 393          Orient    WA  99160
# 2  Sanchez      M      594 White Dale Suite 530      Malad City    ID  83252
# 3    White      M   9443 Cynthia Court Apt. 038         Boulder    MT  59632
# 4   Garcia      M              408 Bradley Rest        Doe Hill    VA  24433
#
#        lat      long  city_pop                                job         dob  \
# 0  36.0788  -81.1781      3495          Psychologist, counselling  1988-03-09
# 1  48.8878 -118.2105       149  Special educational needs teacher  1978-06-21
# 2  42.1808 -112.2620      4154        Nature conservation officer  1962-01-19
# 3  46.2306 -112.1138      1939                    Patent attorney  1967-01-12
# 4  38.4207  -79.4629        99     Dance movement psychotherapist  1986-03-28
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# 1  1f76529f8574734946361c461b024d99  1325376044  49.159047 -118.186462
# 2  a1a22d70485983eac12b5b88dad1cf95  1325376051  43.150704 -112.154481
# 3  6b849c168bdad6f867558c3793159a81  1325376076  47.034331 -112.561071
# 4  a41d7549acf90789359a9aa5346dcb46  1325376186  38.674999  -78.632459
#
#    is_fraud  split
# 0         0  train
# 1         0  train
# 2         0  train
# 3         0  train
# 4         0  train

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1852394 entries, 0 to 1852393
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Unnamed: 0             int64
#  1   trans_date_trans_time  object
#  2   cc_num                 int64
#  3   merchant               object
#  4   category               object
#  5   amt                    float64
#  6   first                  object
#  7   last                   object
#  8   gender                 object
#  9   street                 object
#  10  city                   object
#  11  state                  object
#  12  zip                    int64
#  13  lat                    float64
#  14  long                   float64
#  15  city_pop               int64
#  16  job                    object
#  17  dob                    object
#  18  trans_num              object
#  19  unix_time              int64
#  20  merch_lat              float64
#  21  merch_long             float64
#  22  is_fraud               int64
#  23  split                  object
# dtypes: float64(5), int64(6), object(13)
# memory usage: 339.2+ MB

# %%
#Check Nulls
df.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# split                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud', 'split'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0','street','state','first','last','trans_num','unix_time'],inplace=True)

# %%
df.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt gender            city    zip      lat      long  \
# 0       misc_net    4.97      F  Moravian Falls  28654  36.0788  -81.1781
# 1    grocery_pos  107.23      F          Orient  99160  48.8878 -118.2105
# 2  entertainment  220.11      M      Malad City  83252  42.1808 -112.2620
# 3  gas_transport   45.00      M         Boulder  59632  46.2306 -112.1138
# 4       misc_pos   41.96      M        Doe Hill  24433  38.4207  -79.4629
#
#    city_pop                                job         dob  merch_lat  \
# 0      3495          Psychologist, counselling  1988-03-09  36.011293
# 1       149  Special educational needs teacher  1978-06-21  49.159047
# 2      4154        Nature conservation officer  1962-01-19  43.150704
# 3      1939                    Patent attorney  1967-01-12  47.034331
# 4        99     Dance movement psychotherapist  1986-03-28  38.674999
#
#    merch_long  is_fraud  split
# 0  -82.048315         0  train
# 1 -118.186462         0  train
# 2 -112.154481         0  train
# 3 -112.561071         0  train
# 4  -78.632459         0  train

# %%
#Change date type
df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'],format='mixed')

# %%
df['hour'] = df['trans_date_trans_time'].dt.hour
df['day'] = df['trans_date_trans_time'].dt.day_name()
df['month'] = df['trans_date_trans_time'].dt.month

# %%
df['merchant'] = df['merchant'].apply(lambda x : x.replace('fraud_',''))

# %%
df[['merchant']].head()
# Out:
#                        merchant
# 0          Rippin, Kub and Mann
# 1     Heller, Gutmann and Zieme
# 2                Lind-Buckridge
# 3  Kutch, Hermiston and Farrell
# 4                 Keeling-Crist

# %%
df['dob'] = pd.to_datetime(df['dob'],format='mixed')
df['age'] = (df['trans_date_trans_time'].dt.year - df['dob'].dt.year).astype(int)
df.drop(columns='dob',inplace=True)

# %%
df['distance_km'] = df.apply(lambda col : round(great_circle((col['lat'],col['long']),
                                         (col['merch_lat'],col['merch_long'])).kilometers,2),axis=1)

# %%
df.drop(columns=['lat','long','merch_lat','merch_long'],inplace=True)

# %%
df.head(2)
# Out:
#   trans_date_trans_time            cc_num                   merchant  \
# 0   2019-01-01 00:00:18  2703186189652095       Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322  Heller, Gutmann and Zieme
#
#       category     amt gender            city    zip  city_pop  \
# 0     misc_net    4.97      F  Moravian Falls  28654      3495
# 1  grocery_pos  107.23      F          Orient  99160       149
#
#                                  job  is_fraud  split  hour      day  month  \
# 0          Psychologist, counselling         0  train     0  Tuesday      1
# 1  Special educational needs teacher         0  train     0  Tuesday      1
#
#    age  distance_km
# 0   31        78.60
# 1   41        30.21

# %%
#Summary stats
df.describe().T
# Out:
#                            count                           mean  \
# trans_date_trans_time    1852394  2020-01-20 21:31:46.801827328
# cc_num                 1852394.0           417386038393710400.0
# amt                    1852394.0                      70.063567
# zip                    1852394.0                   48813.258191
# city_pop               1852394.0                   88643.674509
# is_fraud               1852394.0                        0.00521
# hour                   1852394.0                      12.806119
# month                  1852394.0                       7.152067
# age                    1852394.0                       46.21138
# distance_km            1852394.0                      76.111833
#
#                                        min                            25%  \
# trans_date_trans_time  2019-01-01 00:00:18  2019-07-23 04:13:43.750000128
# cc_num                       60416207185.0              180042946491150.0
# amt                                    1.0                           9.64
# zip                                 1257.0                        26237.0
# city_pop                              23.0                          741.0
# is_fraud                               0.0                            0.0
# hour                                   0.0                            7.0
# month                                  1.0                            4.0
# age                                   14.0                           33.0
# distance_km                           0.02                          55.32
#
#                                        50%                            75%  \
# trans_date_trans_time  2020-01-02 01:15:31  2020-07-23 12:11:25.249999872
# cc_num                  3521417320836166.0             4642255475285942.0
# amt                                  47.45                           83.1
# zip                                48174.0                        72042.0
# city_pop                            2443.0                        20328.0
# is_fraud                               0.0                            0.0
# hour                                  14.0                           19.0
# month                                  7.0                           10.0
# age                                   44.0                           57.0
# distance_km                          78.22                          98.51
#
#                                          max                    std
# trans_date_trans_time    2020-12-31 23:59:34                    NaN
# cc_num                 4992346398065154048.0  1309115265318734848.0
# amt                                  28948.9             159.253975
# zip                                  99921.0           26881.845966
# city_pop                           2906700.0          301487.618344
# is_fraud                                 1.0               0.071992
# hour                                    23.0               6.815753
# month                                   12.0               3.424954
# age                                     96.0              17.395446
# distance_km                           152.12              29.117007

# %%
df.describe(include='object').T
# Out:
#             count unique                top     freq
# merchant  1852394    693        Kilback LLC     6262
# category  1852394     14      gas_transport   188029
# gender    1852394      2                  F  1014749
# city      1852394    906         Birmingham     8040
# job       1852394    497  Film/video editor    13898
# split     1852394      2              train  1296675
# day       1852394      7             Monday   369418

# %%
sns.heatmap(df.select_dtypes(include='number').corr(),
            annot=None,cmap='coolwarm',fmt='.2f',linewidths=0.5,cbar_kws={"shrink": 0.8})
plt.title('Correlation Matrix')
plt.show()

# %%
df.select_dtypes(include='number').corr()
# Out:
#                cc_num       amt       zip  city_pop  is_fraud      hour  \
# cc_num       1.000000  0.001826  0.041504 -0.009118 -0.001125 -0.000902
# amt          0.001826  1.000000  0.001979  0.004921  0.209308 -0.024891
# zip          0.041504  0.001979  1.000000  0.077601 -0.002190  0.005947
# city_pop    -0.009118  0.004921  0.077601  1.000000  0.000325  0.019949
# is_fraud    -0.001125  0.209308 -0.002190  0.000325  1.000000  0.013196
# hour        -0.000902 -0.024891  0.005947  0.019949  0.013196  1.000000
# month       -0.000188 -0.002593  0.001160 -0.000510 -0.016417 -0.000986
# age         -0.000131 -0.010695  0.010359 -0.090889  0.010927 -0.173014
# distance_km  0.003082 -0.000538  0.006750  0.010989  0.000359  0.000391
#
#                 month       age  distance_km
# cc_num      -0.000188 -0.000131     0.003082
# amt         -0.002593 -0.010695    -0.000538
# zip          0.001160  0.010359     0.006750
# city_pop    -0.000510 -0.090889     0.010989
# is_fraud    -0.016417  0.010927     0.000359
# hour        -0.000986 -0.173014     0.000391
# month        1.000000  0.000060    -0.000067
# age          0.000060  1.000000    -0.004155
# distance_km -0.000067 -0.004155     1.000000

# %%
def bar_plot(col):
    def top_frauds(col):
        return pd.DataFrame(df.loc[df['is_fraud']==1,[col]].value_counts()).reset_index().head(10)
    ax=sns.barplot(data=top_frauds(col),x=col,y='count',palette='bone')
    ax.bar_label(ax.containers[0])
    plt.title(f'Top 10 Frauds | {col}',fontsize=16,fontweight='bold')
    plt.xticks(rotation=45,fontweight='bold')

# %%
plt.figure(figsize=(17,15))
for idx,val in enumerate(['cc_num','merchant','category','city','job','age']):
    plt.subplot(3,2,idx+1)
    bar_plot(val)
plt.tight_layout()

# %%
#Amount
sns.catplot(data=df,x='amt',col='is_fraud',kind='box',sharex=False)

# %%
def pie_bar_plot(col):
    print(df[col].value_counts())
    sns.set_palette('viridis')
    fig,axs=plt.subplots(1,2)
    axs[0].pie(df[col].value_counts().values.tolist(),autopct='%.2f%%',textprops={'fontsize':25},explode=[0,0.05],shadow=True)
    sns.countplot(data=df,x=col,ax=axs[1])
    fig.legend(labels=df[col].value_counts().index.tolist(),loc='upper left',fontsize=20)
    fig.tight_layout()
    fig.show()

# %%
#Gender
pie_bar_plot('gender')
# Out:
# gender
# F    1014749
# M     837645
# Name: count, dtype: int64

# %%
#Frauds
pie_bar_plot('is_fraud')
# Out:
# is_fraud
# 0    1842743
# 1       9651
# Name: count, dtype: int64

# %%
#What is the most month|day|hour frauds occur?
fig,axs = plt.subplots(3,2)
#Month
df.loc[df['is_fraud']==1,'month'].value_counts().sort_index().plot(kind='line',ax=axs[0,0],marker='o',fontsize=15)
axs[0,0].set_xticks(range(0,12))
df.loc[df['is_fraud']==1,'month'].value_counts(ascending=True).plot(kind='bar',ax=axs[0,1],fontsize=15)
fig.suptitle('Fraudulent Analysis', fontsize=18, fontweight='bold')
##Day
df.loc[df['is_fraud']==1,'day'].value_counts(ascending=True).plot(kind='line',ax=axs[1,0],marker='o',fontsize=15)
df.loc[df['is_fraud']==1,'day'].value_counts(ascending=True).plot(kind='bar',ax=axs[1,1],fontsize=15)
#Hour 
df.loc[df['is_fraud']==1,'hour'].value_counts().sort_index().plot(kind='line',ax=axs[2,0],marker='o',fontsize=15)
axs[2,0].set_xticks(range(0,24))
df.loc[df['is_fraud']==1,'hour'].value_counts(ascending=True).plot(kind='bar',ax=axs[2,1],fontsize=15)
fig.suptitle('Fraudulent Analysis', fontsize=20, fontweight='bold')
plt.tight_layout()

# %%
df.loc[df['is_fraud']==1,['gender']].value_counts()
#Males and females exposed to fraud equally (approximately)
# Out:
# gender
# F         4899
# M         4752
# Name: count, dtype: int64

# %%
sns.barplot(data=df,x='is_fraud', y='city_pop', ci=None)
plt.title('Average city_population for Fraud and Non-Fraud Cases',fontsize=15)
plt.show()

fraud_population = df[df['is_fraud'] == 1]['city_pop']
non_fraud_population = df[df['is_fraud'] == 0]['city_pop']
t_stat, p_value = ttest_ind(fraud_population, non_fraud_population)
print(f'T-test: t-statistic = {round(t_stat,3)}, p-value = {round(p_value,3)}, p-value<0.05? {p_value<0.05}')
# Out:
# T-test: t-statistic = 0.443, p-value = 0.658, p-value<0.05? False

# %%
df.head(3)
# Out:
#   trans_date_trans_time            cc_num                   merchant  \
# 0   2019-01-01 00:00:18  2703186189652095       Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322  Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661             Lind-Buckridge
#
#         category     amt gender            city    zip  city_pop  \
# 0       misc_net    4.97      F  Moravian Falls  28654      3495
# 1    grocery_pos  107.23      F          Orient  99160       149
# 2  entertainment  220.11      M      Malad City  83252      4154
#
#                                  job  is_fraud  split  hour      day  month  \
# 0          Psychologist, counselling         0  train     0  Tuesday      1
# 1  Special educational needs teacher         0  train     0  Tuesday      1
# 2        Nature conservation officer         0  train     0  Tuesday      1
#
#    age  distance_km
# 0   31        78.60
# 1   41        30.21
# 2   57       108.21

# %%
df = pd.get_dummies(df,columns=['gender'],drop_first=True)

# %%
df.sort_values(['cc_num', 'trans_date_trans_time'],inplace=True)
df['hours_diff_bet_trans']=((df.groupby('cc_num')[['trans_date_trans_time']].diff())/np.timedelta64(1,'h'))

# %%
df.loc[df['hours_diff_bet_trans'].isna(),'hours_diff_bet_trans'] = 0
df['hours_diff_bet_trans'] = df['hours_diff_bet_trans'].astype(int)

# %%
#The power of pingouin library!
print(pingouin.ttest(df[df['is_fraud'] == 0]['hours_diff_bet_trans'],
              df[df['is_fraud'] == 1]['hours_diff_bet_trans'],
              alternative='two-sided')[['T','p-val']])
sns.barplot(data=df,x='is_fraud',y='hours_diff_bet_trans',ci=None)
plt.show()
# Out:
#                 T          p-val
# T-test  27.266899  7.200860e-158

# %%
df['day'] = df['trans_date_trans_time'].dt.weekday

# %%
freq = df.groupby('cc_num').size()
df['cc_freq'] = df['cc_num'].apply(lambda x : freq[x])
df[['cc_num','cc_freq']].head()
# Out:
#            cc_num  cc_freq
# 1017  60416207185     2196
# 2724  60416207185     2196
# 2726  60416207185     2196
# 2882  60416207185     2196
# 2907  60416207185     2196

# %%
#We got freq for each cc_num
def hist_show(col):
    fig,axs = plt.subplots(1,2,sharex=True)
    for i in [0,1]:
        sns.histplot(df[df["is_fraud"]==i][col], bins=6,ax=axs[i])

# %%
def class_det(x):
    for idx,val in enumerate(list(range(800,5000,800))):
        if x < val:
            return idx+1

# %%
df['cc_freq_class'] = df['cc_freq'].apply(class_det)
print(df['cc_freq_class'].unique())
# Out:
# [3 1 2 4 5 6]

# %%
#Drop unecessary columns
df.drop(columns=['cc_num','trans_date_trans_time','city_pop'],inplace=True)

# %%
df.columns
# Out:
# Index(['merchant', 'category', 'amt', 'city', 'zip', 'job', 'is_fraud',
#        'split', 'hour', 'day', 'month', 'age', 'distance_km', 'gender_M',
#        'hours_diff_bet_trans', 'cc_freq', 'cc_freq_class'],
#       dtype='object')

# %%
#Reorder columns
df = df[['cc_freq','cc_freq_class','city','job','age','gender_M','merchant', 'category',
         'distance_km','month','day','hour','hours_diff_bet_trans','amt','is_fraud','split']]
df.head()
# Out:
#       cc_freq  cc_freq_class           city                          job  age  \
# 1017     2196              3  Fort Washakie  Information systems manager   33
# 2724     2196              3  Fort Washakie  Information systems manager   33
# 2726     2196              3  Fort Washakie  Information systems manager   33
# 2882     2196              3  Fort Washakie  Information systems manager   33
# 2907     2196              3  Fort Washakie  Information systems manager   33
#
#       gender_M                     merchant       category  distance_km  \
# 1017     False  Jones, Sawayn and Romaguera       misc_net       127.61
# 2724     False                    Berge LLC  gas_transport       110.31
# 2726     False                 Luettgen PLC  gas_transport        21.79
# 2882     False                Daugherty LLC      kids_pets        87.20
# 2907     False               Beier and Sons           home        74.21
#
#       month  day  hour  hours_diff_bet_trans    amt  is_fraud  split
# 1017      1    1    12                     0   7.27         0  train
# 2724      1    2     8                    19  52.94         0  train
# 2726      1    2     8                     0  82.08         0  train
# 2882      1    2    12                     3  34.79         0  train
# 2907      1    2    13                     0  27.18         0  train

# %%
for col in ['city','job','merchant', 'category']:
    df[col] = WOEEncoder().fit_transform(df[col],df['is_fraud'])

# %%
df.head()
# Out:
#       cc_freq  cc_freq_class      city       job  age  gender_M  merchant  \
# 1017     2196              3 -0.193426  0.163804   33     False  0.472059
# 2724     2196              3 -0.193426  0.163804   33     False -0.499771
# 2726     2196              3 -0.193426  0.163804   33     False -0.132212
# 2882     2196              3 -0.193426  0.163804   33     False -0.620062
# 2907     2196              3 -0.193426  0.163804   33     False -1.296190
#
#       category  distance_km  month  day  hour  hours_diff_bet_trans    amt  \
# 1017  0.925860       127.61      1    1    12                     0   7.27
# 2724 -0.238221       110.31      1    2     8                    19  52.94
# 2726 -0.238221        21.79      1    2     8                     0  82.08
# 2882 -1.019735        87.20      1    2    12                     3  34.79
# 2907 -1.238421        74.21      1    2    13                     0  27.18
#
#       is_fraud  split
# 1017         0  train
# 2724         0  train
# 2726         0  train
# 2882         0  train
# 2907         0  train

# %%
x_train = df[df['split']=='train'].drop(['split','is_fraud'],axis=1)
y_train = df[df['split']=='train']['is_fraud']
x_test = df[df['split']=='test'].drop(['split','is_fraud'],axis=1)
y_test = df[df['split']=='test']['is_fraud']

# %%
plt.figure(figsize=(3,3))
plt.pie([len(x_train),len(x_test)],autopct='%.2f%%'
        ,textprops={'color':'white'},explode=[0,0.05],shadow=True)
plt.legend(['Train','Test'])
plt.show()

# %%
#Handling outliers
x_train.select_dtypes(include='number').columns
# Out:
# Index(['cc_freq', 'cc_freq_class', 'city', 'job', 'age', 'merchant',
#        'category', 'distance_km', 'month', 'day', 'hour',
#        'hours_diff_bet_trans', 'amt'],
#       dtype='object')

# %%
datasets={'x_train':x_train,'x_test':x_test}
cols = ['hours_diff_bet_trans', 'amt']

# %%
def count_outliers(l:list):
    for col in l:
        print(f'Outliers In {col}:',len(detect_outliers(x_train,0,[col])))

# %%
def boxplot_outliers(ds:dict):
    plt.figure(figsize=(18,8))
    c=1
    for _,df_x in ds.items():
        for col in ['hours_diff_bet_trans', 'amt']:
            plt.subplot(2,2,c)
            df_x[col].plot(kind='box',vert=False)
            c+=1        
    plt.suptitle('Detecting Outliers In Train|Test Data',fontsize=20)
    plt.tight_layout()

# %%
count_outliers(cols)
boxplot_outliers(datasets)
# Out:
# Outliers In hours_diff_bet_trans: 86989
# Outliers In amt: 67290

# %%
#Applying log scale
for col in cols:
    x_train[col] = np.log1p(x_train[col])
    x_test[col] = np.log1p(x_test[col])

# %%
count_outliers(cols)
boxplot_outliers(datasets)
# Out:
# Outliers In hours_diff_bet_trans: 222
# Outliers In amt: 818

# %%
scaler = StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
evl_models = {'Logistic Regression':LogisticRegression(random_state=10),
          'Decision Tree':DecisionTreeClassifier(random_state=10),
          'Random Forest':RandomForestClassifier(random_state=10)}

# %%
def evl_model(xtrain,ytrain,xtest,ytest):
    sns.set(rc={'figure.figsize':(18,6)})
    i=0
    for name,model in evl_models.items():
        fig,axs=plt.subplots(1,2)
        print('Model : '+name)
        print('_'*30)
        start=time()
        model.fit(xtrain,ytrain)
        y_pred = model.predict(xtest)
        end=time()
        #Confusion Matrix
        cm = confusion_matrix(ytest,y_pred,labels=model.classes_)
        cmd = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model.classes_)
        cmd.plot(colorbar=False,ax=axs[i])
        axs[i].grid(False)
        #AUC-ROC Curve
        y_proba = model.predict_proba(xtest)
        fpr, tpr, _ = roc_curve(ytest, y_proba[:, 1])
        roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr).plot(ax=axs[i+1])
        axs[i+1].plot([0, 1], [0, 1], color = 'g')
        plt.tight_layout()
        plt.show()
        #We focus on recall=TP/TP+FN
        #such that it's the score that model predict(non-fraud) while it's fraud.
        print('Recall Score: ',recall_score(ytest,y_pred))
        print('Precision: ',precision_score(ytest,y_pred))
        print('F1-Score: ',f1_score(ytest,y_pred))
        print('Accuracy Score: ',accuracy_score(ytest,y_pred))
        print('AUC Score: ',roc_auc_score(ytest,y_proba[:,1]))
        print('Running Time : ',round((end-start)/60.0,2),'Mins')
        print('*'*30)

# %%
evl_model(x_train,y_train,x_test,y_test)
# Out:
# Model : Logistic Regression
# ______________________________
# No handles with labels found to put in legend.
# Recall Score:  0.1916083916083916
# Precision:  0.8253012048192772
# F1-Score:  0.3110102156640182
# Accuracy Score:  0.9967231640451379
# AUC Score:  0.8631322009132382
# Running Time :  0.11 Mins
# ******************************
# Model : Decision Tree
# ______________________________
# No handles with labels found to put in legend.
# Recall Score:  0.7794871794871795
# Precision:  0.7263249348392702
# F1-Score:  0.7519676186192938
# Accuracy Score:  0.9980151839328869
# AUC Score:  0.8891745601287595
# Running Time :  0.41 Mins
# ******************************
# Model : Random Forest
# ______________________________

# %%
smote = SMOTE()
x_train,y_train = smote.fit_resample(x_train,y_train)

# %%
y_train.value_counts().plot(kind='pie',figsize=(4,4),autopct='%.2f%%',textprops={'color':'white'},labels=['Fraud','Non-Fraud'],legend=True)

# %%
evl_model(x_train,y_train,x_test,y_test)
